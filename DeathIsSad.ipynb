# %%
# Imports
#  Note: these are all the imports you need! Do not import any other functions / packages
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
df_death = pd.read_csv('DeathRecords.csv')

# %%
corrGraph = df_death.corr().abs()
corrGraph
# Out:
#                                       Id  ResidentStatus  \
# Id                              1.000000        0.152101
# ResidentStatus                  0.152101        1.000000
# Education1989Revision           0.040731        0.011442
# Education2003Revision           0.010469        0.006548
# EducationReportingFlag          0.052488        0.017226
# MonthOfDeath                    0.037319        0.001201
# AgeType                         0.000227        0.036733
# Age                             0.003537        0.055055
# AgeSubstitutionFlag             0.001438        0.001107
# AgeRecode52                     0.003163        0.082679
# AgeRecode27                     0.003457        0.087858
# AgeRecode12                     0.003149        0.085581
# InfantAgeRecode22               0.000424        0.027152
# PlaceOfDeathAndDecedentsStatus  0.014080        0.151419
# DayOfWeekOfDeath                0.000068        0.002156
# ...

# %%
# corrMost = corrGraph['Icd10Code'].unstack().sort_values(kind="quicksort", ascending=False)
print(corrGraph['Icd10Code'])

# corrMost = corrMost[corrMost[2] != 1]
# corrMost = corrMost[corrMost!=1.0 ]
# corrMost[corrMost < .35 ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Icd10Code'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
corrMost =
# Out:
# pandas.core.series.Series
